# %% [markdown]
# <a href="https://colab.research.google.com/github/mayborgws/mayborgws/blob/main/Exerc%C3%ADcios_Python_Mundo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Crie um programa que leia dois números e mostre a soma entre eles
n1 = int(input('Digite um valor: '))
n2 = int(input('Digite putro valor'))
s = n1 + n2
print(f'A soma entre {n1} e {n2} é igual a {s}!')
# Out:
# Digite um valor: 25
# Digite putro valor5
# A soma entre 25 e 5 é igual a 30!

# %%
#Faça um programa que leia algo pelo teclado e mostre na tela o seu tipo primitivo e
#todas as informações possiveis sobre ela

a = input('Digite algo: ')
print('O tipo primitivo desse valor é ', type(a))
print('Só tem espaços?', a.isspace())
print('É um número?', a.isnumeric())
# Out:
# Digite algo: 3
# O tipo primitivo desse valor é  <class 'str'>
# Só tem espaços? False
# É um número? True
